# %%
user_age=29
guest_age=int(input("Enter your age:"))
if user_age==guest_age:
    print(f"We both are {user_age} years old")
elif user_age>guest_age:
    age_diff=user_age-guest_age
    if age_diff<2:
        print(f"I am only a year older than you")
    else:
        print(f"I am {age_diff} years older than you")
else:
    age_diff=guest_age-user_age
    if age_diff<2:
        print(f"You are only a year older than me")
    else:
        print(f"You are {age_diff} years older than me")
# Out:
# We both are 29 years old

# %%
text ="This is python the king of AI"
print (text[::-1])
# Out:
# IA fo gnik eht nohtyp si sihT

# %%
text = "1023 "
print(text *10)
# Out:
# 1023 1023 1023 1023 1023 1023 1023 1023 1023 1023

# %%
num1=int(input("Enter 1st number: "))
num2=int(input("Enter 2nd number: "))
if num1>num2:
    print(f"{num1} is greater than {num2}")
elif num1<num2:
    print(f"{num1} is less than {num2}")
else:
    print(f"{num1} is equal to {num2}")
# Out:
# 2 is equal to 2

# %%
str="Python"
print(str.startswith('P'))
print(str.startswith('a'))
print(str.endswith('n'))
print(str.endswith('N'))
print(str.isalpha())
print(str.isdigit())
print(str.isalnum())
# Out:
# True
# False
# True
# False
# True
# False
# True

# %%
for i in range(1,3):
    for j in range(3,6):
        print(f"{i},{j}")
# Out:
# 1,3
# 1,4
# 1,5
# 2,3
# 2,4
# 2,5

# %%
start=int(input("Enter the starting range :"))
end=int(input("Enter the ending range :"))
skip=int(input("Enter the number you want to skip:"))

if start>end:
    print("Ending cannot be less than starting range")
elif skip < start or skip > end:
    print("Skip should be in between the range")
# Out:
# 12
# 13
# 15
# 16
# 17
